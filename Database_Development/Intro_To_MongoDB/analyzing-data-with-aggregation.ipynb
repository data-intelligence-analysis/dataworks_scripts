# %%
from pymongo import MongoClient
import pymongo
import pprint

# %%
client = MongoClient('mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')

# %%
trips = client.citibike.trips

# %%
# Replace XXXX with your aggregation pipeline to answer the question:
# Citibike trips that start at station id 279 end most frequently at what station id?
pipeline = [
    
    {'$match':{'start station id':279}},
    {
        '$facet': {
            'highest count for start station id':[{'$sortByCount':'$start station id'}],
            'highest count for end station id': [{'$sortByCount':'$end station id'}]
        }
        
    }
     
]

#filter = {'start station id':279}
#pprint.pprint(list(client.citibike.trips.find(filter)))

# %%
# print the results
for trip in trips.aggregate(pipeline):
    pprint.pprint(trip)
# Out:
# {'highest count for end station id': [{'_id': 279, 'count': 137},
#                                       {'_id': 316, 'count': 112},
#                                       {'_id': 259, 'count': 104},
#                                       {'_id': 387, 'count': 99},
#                                       {'_id': 224, 'count': 86},
#                                       {'_id': 306, 'count': 83},
#                                       {'_id': 268, 'count': 80},
#                                       {'_id': 260, 'count': 75},
#                                       {'_id': 308, 'count': 73},
#                                       {'_id': 360, 'count': 71},
#                                       {'_id': 3002, 'count': 63},
#                                       {'_id': 361, 'count': 57},
#                                       {'_id': 337, 'count': 56},
#                                       {'_id': 487, 'count': 55},
# ...
